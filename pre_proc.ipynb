# %%
import torch
import torchvision.transforms as transforms
from dataset import ReadImages
import cv2
import numpy as np
from os import path
from utils_dataset import get_images_labels
from utils_params import match_label_fou_clean2, match_label_video

# %%
dataset = '/home/mrim/data/collection/GUIMUTEIC/FOURVIERE_CLEAN2/TRAIN_I'
dataset_test = '/home/mrim/data/collection/GUIMUTEIC/FOURVIERE_CLEAN2/TEST_I'
match_labels = match_label_fou_clean2
out_path = './data/pre_proc/fourviere_clean2_448'
out_path_test = './data/pre_proc/fourviere_clean2_448/test'

# training and test sets (scaled to 300 on the small side)
dataSetFull = get_images_labels(dataset, match_labels)
testSetFull = get_images_labels(dataset_test, match_labels)

# %%
def resize(dataset, out_path, max_ar, newsize1, newsize2=None):
    for im, lab in dataset:
        im_o = cv2.imread(im)
        h, w, _ = im_o.shape
        if max_ar >= 1. and ((h > w and float(h) / w > max_ar) or (h < w and float(w) / h > max_ar)):
            # force a max aspect ratio of max_ar by padding image with random uniform noise
            def pad_rand(vector, pad_width, iaxis, kwargs):
                if pad_width[0] > 0:
                    vector[:pad_width[0]] = np.random.randint(256, size=pad_width[0])
                if pad_width[1] > 0:
                    vector[-pad_width[1]:] = np.random.randint(256, size=pad_width[1])
                return vector
            if h > w:
                ow = int(np.ceil(float(h) / max_ar))
                w_pad = (ow - w) // 2
                w_mod = (ow - w) % 2
                im_o = np.pad(im_o, ((0, 0), (w_pad + w_mod, w_pad), (0, 0)), pad_rand)
            else:
                oh = int(np.ceil(float(w) / max_ar))
                h_pad = (oh - h) // 2
                h_mod = (oh - h) % 2
                im_o = np.pad(im_o, ((h_pad + h_mod, h_pad), (0, 0), (0, 0)), pad_rand)
        h, w, _ = im_o.shape
        if newsize2 is None:
            if (w <= h and w == newsize1) or (h <= w and h == newsize1):
                ow, oh = w, h
            elif (w < h):
                ow, oh = newsize1, int(round(float(newsize1 * h) / w))
            else:
                ow, oh = int(round(float(newsize1 * w) / h)), newsize1
        else:
            ow, oh = newsize1, newsize2
        if ow == w and oh == h:
            im_out = im_o
        else:
            im_out = cv2.resize(im_o, (ow, oh), interpolation=cv2.INTER_CUBIC)
        out_p = path.join(out_path, im.split('/')[-1])
        print('/'.join(im.split('/')[-3:]), '->', '/'.join(out_p.split('/')[-3:]))
        cv2.imwrite(out_p, im_out)

# %%
resize(dataSetFull, out_path, 2.0, 448)
resize(testSetFull, out_path_test, 2.0, 448)
# Out:
# ('FOURVIERE_CLEAN2/TRAIN_I/D_084_04.jpg', '->', 'pre_proc/fourviere_clean2_448/D_084_04.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_084_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_084_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_084_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_084_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_084_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_084_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_084_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_084_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_083_04.jpg', '->', 'pre_proc/fourviere_clean2_448/D_083_04.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_083_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_083_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_083_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_083_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_083_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_083_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_083_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_083_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_16.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_16.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_15.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_15.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_14.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_14.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_13.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_13.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_12.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_12.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_11.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_11.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_10.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_10.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_09.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_09.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_08.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_08.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_07.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_07.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_06.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_06.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_05.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_05.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_04.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_04.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_082_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_082_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_09.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_09.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_08.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_08.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_07.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_07.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_06.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_06.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_05.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_05.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_04.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_04.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_081_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_081_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_080_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_080_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_080_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_080_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_080_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_080_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_079_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_079_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_079_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_079_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_079_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_079_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_078_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_078_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_078_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_078_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_078_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_078_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_077_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_077_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_077_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_077_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_077_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_077_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_077_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_077_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_07.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_07.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_06.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_06.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_05.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_05.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_04.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_04.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_076_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_076_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_075_04.jpg', '->', 'pre_proc/fourviere_clean2_448/D_075_04.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_075_03.jpg', '->', 'pre_proc/fourviere_clean2_448/D_075_03.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_075_02.jpg', '->', 'pre_proc/fourviere_clean2_448/D_075_02.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_075_01.jpg', '->', 'pre_proc/fourviere_clean2_448/D_075_01.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D_075_00.jpg', '->', 'pre_proc/fourviere_clean2_448/D_075_00.jpg')
# ('FOURVIERE_CLEAN2/TRAIN_I/D